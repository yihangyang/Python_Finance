# %%
# 15.Data Visualization
import matplotlib as mpl
mpl.__version__
# Out:
# '3.0.3'

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn')
import seaborn as sns
mpl.rcParams['font.family'] = 'serif'

# %%
# Static 2D Plotting

# %%
import numpy as np

# %%
np.random.seed(1000)

# %%
y = np.random.standard_normal(20)
y
# Out:
# array([-0.8044583 ,  0.32093155, -0.02548288,  0.64432383, -0.30079667,
#         0.38947455, -0.1074373 , -0.47998308,  0.5950355 , -0.46466753,
#         0.66728131, -0.80611561, -1.19606983, -0.40596016, -0.18237734,
#         0.10319289, -0.13842199,  0.70569237,  1.27179528, -0.98674733])

# %%
y_ = np.random.randn(20)
y_
# Out:
# array([-0.33483545, -0.0994817 ,  0.4071921 ,  0.91938754,  0.31211801,
#         1.53316107, -0.55017387, -0.38314741, -0.82294096,  1.60008337,
#        -0.0692813 ,  0.08320949, -0.32692468, -0.04579719, -0.30446006,
#         1.92301013, -0.078659  , -0.58206572, -1.61798224,  0.86726082])

# %%
x = np.arange(1,len(y) + 1)
plt.plot(y)

# %%
plt.plot(y)

# %%
plt.plot(y.cumsum())

# %%
plt.plot(y.cumsum())
plt.grid(False)
plt.axis('equal')
# Out:
# (-0.9500000000000001, 19.95, -2.322818663749045, 0.5655085808655865)

# %%
plt.plot(y.cumsum())
plt.xlim(-1,20)
plt.ylim(np.min(y.cumsum()) - 1,np.max(y.cumsum()) + 1)
# Out:
# (-3.1915310617211072, 1.4342209788376488)

# %%
plt.figure(figsize=(10,6))
plt.plot(y.cumsum(),'b',lw = 1.5) # blue
plt.plot(y.cumsum(),'ro') #red oooo
plt.xlabel('index')
plt.ylabel('value')
plt.title('A Simple Plot')
# Out:
# Text(0.5, 1.0, 'A Simple Plot')

# %%
# Two Dimensional Data Set
y = np.random.standard_normal((20,2)).cumsum(axis = 0)
y
# Out:
# array([[-1.04043709,  0.65042142],
#        [ 1.65920877,  1.45244594],
#        [ 0.56228751,  1.27439149],
#        [ 0.13941704,  0.94399095],
#        [-0.97174574,  0.20198519],
#        [ 1.60301345,  1.27519852],
#        [-0.26312106,  0.62802159],
#        [ 0.81911975,  0.80469191],
#        [-0.01620848, -0.89030641],
#        [ 1.11720875,  0.15822431],
#        [-1.01111662, -1.27891508],
#        [-0.83317951,  0.11550767],
#        [-0.54185933,  0.03350147],
#        [ 0.10238328,  0.36158142],
#        [ 0.95981603, -0.57538786],
#        [ 1.13989099, -1.99875845],
#        [ 0.77213521, -3.52204644],
#        [ 0.13736351, -2.5346426 ],
#        [-0.87865611, -0.48891885],
#        [-0.62865759,  0.16224368]])

# %%
plt.figure(figsize=(10,6))
plt.plot(y,lw = 1.5)
plt.plot(y,'ro')
plt.xlabel('index')
plt.ylabel('value')
plt.title('A Simple Plot')
# Out:
# Text(0.5, 1.0, 'A Simple Plot')

# %%
plt.figure(figsize=(10,6))
plt.plot(y[:,0],lw = 1.5,label = '1st')
plt.plot(y[:,1],lw = 1.5,label = '2nd')
plt.plot(y,'ro')
plt.legend(loc = 0) # 0 stands for automatic for best location
plt.xlabel('index')
plt.ylabel('value')
plt.title('A Simple Plot')
# Out:
# Text(0.5, 1.0, 'A Simple Plot')

# %%
y[:,0] = y[:,0] * 100

# %%
plt.figure(figsize=(10,6))
plt.plot(y[:,0],lw = 1.5,label = '1st')
plt.plot(y[:,1],lw = 1.5,label = '2nd')
plt.plot(y,'ro')
plt.legend(loc = 0) # 0 stands for automatic for best location
plt.xlabel('index')
plt.ylabel('value')
plt.title('A Simple Plot')
# Out:
# Text(0.5, 1.0, 'A Simple Plot')

# %%
fig,ax1 = plt.subplots()

plt.plot(y[:,0],lw = 1.5,label = '1st')
plt.plot(y[:,0],'ro')
plt.legend(loc = 8)
plt.xlabel('index')
plt.ylabel('value 1st')
plt.title('A Simple Plot')

ax2 = ax1.twinx()
plt.plot(y[:,1],'g',lw = 1.5,label = '2nd')
plt.plot(y[:,1],'ro')
plt.legend(loc = 0)
plt.ylabel('value 2nd')
# Out:
# Text(0, 0.5, 'value 2nd')

# %%
plt.figure(figsize = (10,6))

plt.subplot(211)
plt.plot(y[:,0],lw = 1.5,label = '1st')
plt.plot(y[:,0],'ro')
plt.legend(loc = 0)
plt.ylabel('value')
plt.title('A Simple Plot')

plt.subplot(212)
plt.plot(y[:,1],'g',lw = 1.5,label = '2nd')
plt.plot(y[:,1],'ro')
plt.legend(loc = 0)
plt.xlabel('index')
plt.ylabel('value')
# Out:
# Text(0, 0.5, 'value')

# %%
plt.figure(figsize = (10,6))

plt.subplot(121)
plt.plot(y[:,0],lw = 1.5,label = '1st')
plt.plot(y[:,0],'ro')
plt.legend(loc = 0)
plt.xlabel('index')
plt.ylabel('value')
plt.title('1st Data Set')

plt.subplot(122)
plt.bar(np.arange(len(y)),y[:,1],width = 0.5,color = 'g',label = '2nd')
plt.legend(loc = 0)
plt.xlabel('index')
plt.title('2nd Data Set')
# Out:
# Text(0.5, 1.0, '2nd Data Set')

# %%
#other Plot Styles
y = np.random.standard_normal((1000,2))
y
# Out:
# array([[-1.26602354,  1.3741556 ],
#        [-0.60990513,  0.03075795],
#        [ 0.81965668,  1.45431373],
#        ...,
#        [-0.54805961,  1.44275127],
#        [ 1.06188143, -1.58068179],
#        [ 1.15277358, -0.15106464]])

# %%
plt.figure(figsize=(6,6))
plt.plot(y[:,0],y[:,1],'r.')
plt.xlabel('1st')
plt.ylabel('2nd')
plt.title('Scatter Plot')
# Out:
# Text(0.5, 1.0, 'Scatter Plot')

# %%
plt.figure(figsize=(6,6))
plt.scatter(y[:,0],y[:,1],marker='o')

# %%
c = np.random.randint(0,10,len(y)) #0-9,len(y)个整数随机数

# %%
plt.figure(figsize = (10,6))
plt.scatter(y[:,0],y[:,1],c = c, #color = s随机数
           cmap = 'coolwarm',marker = 'o')
plt.colorbar()
plt.xlabel('1st')
plt.ylabel('2st')
plt.title('Scatter Plot')
# Out:
# Text(0.5, 1.0, 'Scatter Plot')

# %%
plt.figure(figsize = (10,6))
plt.hist(y,label=['1st','2nd'],bins = 25)
plt.legend(loc = 0)
plt.xlabel('value')
plt.ylabel('frequency')
plt.title('Histogram')
# Out:
# Text(0.5, 1.0, 'Histogram')

# %%
plt.figure(figsize=(10,6))
plt.hist(y,label = ['1st','2st'],color = ['b','g'],
         stacked = True,#交叉形式的直方图
         bins = 20,
         alpha = 0.5 # 透明度
        )
plt.legend(loc = 0)
plt.xlabel('value')
plt.ylabel('frequency')
plt.title('Histogram')
# Out:
# Text(0.5, 1.0, 'Histogram')

# %%
fig,ax = plt.subplots(figsize = (10,6))
plt.boxplot(y)
plt.setp(ax,xticklabels =['1st','2nd'])
plt.xlabel = ('data set')
plt.ylabel = ('value')
plt.title = ('Boxplot')

# %%
fig = plt.figure()  # 创建画布
ax = plt.subplot()  # 创建作图区域
# 蓝色矩形的红线：50%分位点是4.5,上边沿：25%分位点是2.25,下边沿：75%分位点是6.75
ax.boxplot([range(5), range(10), range(20)])
plt.show()

# %%
fig = plt.figure()  # 创建画布
ax = plt.subplot()  # 创建作图区域
ax.boxplot([range(5), range(10), range(20)], whis=[5, 95])   # 设置最大值不超过95分位点；最小值不小于5%分位点。
plt.show()

# %%
fig = plt.figure()  # 创建画布
ax = plt.subplot()  # 创建作图区域
# 缺口表示50%分位点的置信区间，缺口太大表示分布太分散了
ax.boxplot([range(5), range(10), range(20)], notch=True)
# 修改x轴下标
ax.set_xticks([1, 2, 3])
ax.set_xticklabels(['first', 'second', 'third'])
# 显示y坐标轴的底线
plt.grid(axis='y')
plt.show()

# %%
np.random.seed(19680801)
all_data = [np.random.normal(0, std, size=100) for std in range(1, 4)]
labels = ['x1', 'x2', 'x3']

bplot = plt.boxplot(all_data, patch_artist=True, labels=labels)  # 设置箱型图可填充
#plt.title('Rectangular box plot')

colors = ['pink', 'lightblue', 'lightgreen']
for patch, color in zip(bplot['boxes'], colors):
    patch.set_facecolor(color)  # 为不同的箱型图填充不同的颜色

#plt.yaxis.grid(True)
plt.xlabel('Three separate samples')
plt.ylabel('Observed values')
plt.show()

# %%
np.random.seed(19680801)
all_data = [np.random.normal(0, std, size=100) for std in range(1, 4)]
labels = ['x1', 'x2', 'x3']

bplot = plt.boxplot(all_data, patch_artist=True, labels=labels)  # 设置箱型图可填充
plt.title('Rectangular box plot')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8c213cf5c772> in <module>
# ----> 1 np.random.seed(19680801)
#       2 all_data = [np.random.normal(0, std, size=100) for std in range(1, 4)]
#       3 labels = ['x1', 'x2', 'x3']
#       4
#       5 bplot = plt.boxplot(all_data, patch_artist=True, labels=labels)  # 设置箱型图可填充
#
# NameError: name 'np' is not defined
