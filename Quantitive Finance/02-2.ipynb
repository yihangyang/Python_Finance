# %%
import numpy as np
import pandas as pd
import scipy as sp
import matplotlib.pyplot as plt
import pandas_datareader.data as web
import datetime

# %%
datei = pd.read_csv('https://github.com/selva86/datasets/raw/master/mtcars.csv'
                   ,header = None,names =['data1','data2','data3','data4','data5','data6',
                                          'data7','data8','data9','data10','data11','data12','data13','data14'])
datei
# Out:
#                data1 data2  data3 data4 data5  data6  data7 data8 data9  \
# 0                mpg   cyl   disp    hp  drat     wt   qsec    vs    am
# 1   4.58257569495584     6    160   110   3.9   2.62  16.46     0     1
# 2   4.58257569495584     6    160   110   3.9  2.875  17.02     0     1
# 3   4.77493455452533     4    108    93  3.85   2.32  18.61     1     1
# 4   4.62601340248815     6    258   110  3.08  3.215  19.44     1     0
# 5   4.32434966208793     8    360   175  3.15   3.44  17.02     0     0
# 6   4.25440947723653     6    225   105  2.76   3.46  20.22     1     0
# 7   3.78153408023781     8    360   245  3.21   3.57  15.84     0     0
# 8   4.93963561409139     4  146.7    62  3.69   3.19     20     1     0
# 9   4.77493455452533     4  140.8    95  3.92   3.15   22.9     1     0
# 10  4.38178046004133     6  167.6   123  3.92   3.44   18.3     1     0
# 11   4.2190046219458     6  167.6   123  3.92   3.44   18.9     1     0
# ...

# %%
data = pd.read_csv('https://github.com/selva86/datasets/raw/master/mtcars.csv',header = 0,index_col = 'mpg')
#na_value = ['.','none']
data
# Out:
#           cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb  fast  \
# mpg
# 4.582576    6  160.0  110  3.90  2.620  16.46   0   1     4     4     1
# 4.582576    6  160.0  110  3.90  2.875  17.02   0   1     4     4     1
# 4.774935    4  108.0   93  3.85  2.320  18.61   1   1     4     1     1
# 4.626013    6  258.0  110  3.08  3.215  19.44   1   0     3     1     1
# 4.324350    8  360.0  175  3.15  3.440  17.02   0   0     3     2     1
# 4.254409    6  225.0  105  2.76  3.460  20.22   1   0     3     1     1
# 3.781534    8  360.0  245  3.21  3.570  15.84   0   0     3     4     0
# 4.939636    4  146.7   62  3.69  3.190  20.00   1   0     4     2     1
# 4.774935    4  140.8   95  3.92  3.150  22.90   1   0     4     2     1
# 4.381780    6  167.6  123  3.92  3.440  18.30   1   0     4     4     1
# 4.219005    6  167.6  123  3.92  3.440  18.90   1   0     4     4     1
# 4.049691    8  275.8  180  3.07  4.070  17.40   0   0     3     3     1
# ...

# %%
#data1.to_csv(path)
#data = pd.read_excel(path,sheet_name = 'GOOG')

# %%
from numpy import nan
data = pd.DataFrame([[1.,6.5,3.],[1.,nan,nan],[nan,nan,nan],[nan,6.5,3.]])
data
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  6.5  3.0

# %%
cleaned = data.dropna(axis = 0,how = 'all')
cleaned
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 3  NaN  6.5  3.0

# %%
cleaned = data .dropna(axis = 0)
cleaned
# Out:
#      0    1    2
# 0  1.0  6.5  3.0

# %%
data.fillna('baba')
# Out:
#       0     1     2
# 0     1   6.5     3
# 1     1  baba  baba
# 2  baba  baba  baba
# 3  baba   6.5     3

# %%
data.fillna({0:'first',1:'second',2:'third'})
# Out:
#        0       1      2
# 0      1     6.5      3
# 1      1  second  third
# 2  first  second  third
# 3  first     6.5      3

# %%
data.fillna(data.mean(axis = 0))#用每列的均值
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  6.5  3.0
# 2  1.0  6.5  3.0
# 3  1.0  6.5  3.0

# %%
data.fillna(data.mean(axis = 1))#用每行的均值
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  1.0  NaN
# 2  3.5  1.0  NaN
# 3  3.5  6.5  3.0

# %%
data2 = pd.DataFrame({'k1':['one','two']*3+['two']*2,'k2':[1,1,2,2,3,3,4,4]})

# %%
data2
# Out:
#     k1  k2
# 0  one   1
# 1  two   1
# 2  one   2
# 3  two   2
# 4  one   3
# 5  two   3
# 6  two   4
# 7  two   4

# %%
data2.drop_duplicates()
# Out:
#     k1  k2
# 0  one   1
# 1  two   1
# 2  one   2
# 3  two   2
# 4  one   3
# 5  two   3
# 6  two   4

# %%
data2.drop_duplicates(['k1'],keep='last')
# Out:
#     k1  k2
# 4  one   3
# 7  two   4

# %%
data
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  6.5  3.0

# %%
data = data.fillna(2)
data
# Out:
#      0    1      2
# 0  1.0  6.5  648.0
# 1  1.0  2.0  128.0
# 2  2.0  2.0  128.0
# 3  2.0  6.5  648.0

# %%
data
# Out:
#      0    1      2
# 0  1.0  6.5  648.0
# 1  1.0  2.0  128.0
# 2  2.0  2.0  128.0
# 3  2.0  6.5  648.0

# %%
data[2] = data[2].map(lambda x :x * 2)
data
# Out:
#      0    1       2
# 0  1.0  6.5  1296.0
# 1  1.0  2.0   256.0
# 2  2.0  2.0   256.0
# 3  2.0  6.5  1296.0

# %%
df = np.random.randn(18).reshape(3,6)
ddf = np.arange(16).reshape(4,4)
df
# Out:
# array([[-0.32829214, -0.31341743,  1.53133166,  0.54689674, -1.62207269,
#          2.26519975],
#        [-0.03740478,  0.97859433, -0.47598921, -0.86275601,  1.02611459,
#          0.94149065],
#        [-0.81905371,  0.50362646,  1.04607751,  0.16441237, -1.20247767,
#          2.13609928]])

# %%
df = pd.DataFrame(df).T

# %%
df
# Out:
#           0         1         2
# 0 -0.328292 -0.037405 -0.819054
# 1 -0.313417  0.978594  0.503626
# 2  1.531332 -0.475989  1.046078
# 3  0.546897 -0.862756  0.164412
# 4 -1.622073  1.026115 -1.202478
# 5  2.265200  0.941491  2.136099

# %%
df[df[0]>0]
# Out:
#           0         1         2
# 2  1.531332 -0.475989  1.046078
# 3  0.546897 -0.862756  0.164412
# 5  2.265200  0.941491  2.136099

# %%
df
# Out:
#           0         1         2
# 0 -0.328292 -0.037405 -0.819054
# 1 -0.313417  0.978594  0.503626
# 2  1.531332 -0.475989  1.046078
# 3  0.546897 -0.862756  0.164412
# 4 -1.622073  1.026115 -1.202478
# 5  2.265200  0.941491  2.136099

# %%
df.take(np.random.permutation(6))
# Out:
#           0         1         2
# 1 -0.313417  0.978594  0.503626
# 5  2.265200  0.941491  2.136099
# 4 -1.622073  1.026115 -1.202478
# 0 -0.328292 -0.037405 -0.819054
# 2  1.531332 -0.475989  1.046078
# 3  0.546897 -0.862756  0.164412

# %%
df.sample(n=3,replace=True)#放回抽样
# Out:
#           0         1         2
# 3  0.546897 -0.862756  0.164412
# 5  2.265200  0.941491  2.136099
# 5  2.265200  0.941491  2.136099

# %%
df1 = pd.DataFrame({'key':['b','b','a','c','a','a','b'],'data1':range(7)})
df2 = pd.DataFrame({'key':['a','b','d'],'data2':range(3)})

# %%
df1
# Out:
#   key  datal
# 0   b      0
# 1   b      1
# 2   a      2
# 3   c      3
# 4   a      4
# 5   a      5
# 6   b      6

# %%
df2
# Out:
#   key  datal
# 0   a      0
# 1   b      1
# 2   d      2

# %%
pd.merge(df1,df2,on = 'key')
# Out:
#   key  datal_x  datal_y
# 0   b        0        1
# 1   b        1        1
# 2   b        6        1
# 3   a        2        0
# 4   a        4        0
# 5   a        5        0

# %%
df3 = pd.DataFrame({'lkey':['b','b','a','c','a','a','b'],'data1':range(7)})
df4 = pd.DataFrame({'rkey':['a','b','d'],'data2':range(3)})
#pd.merge(df3,df4,left_on='lkey',right_on = 'rkey')

# %%
pd.merge(df3,df4,left_on='lkey',right_on = 'rkey')#default是inner join,还有left,right,outer
# Out:
#   lkey  data1 rkey  data2
# 0    b      0    b      1
# 1    b      1    b      1
# 2    b      6    b      1
# 3    a      2    a      0
# 4    a      4    a      0
# 5    a      5    a      0

# %%
pd.merge(df3,df4,left_on='lkey',right_on = 'rkey',how = 'outer')
# Out:
#   lkey  data1 rkey  data2
# 0    b    0.0    b    1.0
# 1    b    1.0    b    1.0
# 2    b    6.0    b    1.0
# 3    a    2.0    a    0.0
# 4    a    4.0    a    0.0
# 5    a    5.0    a    0.0
# 6    c    3.0  NaN    NaN
# 7  NaN    NaN    d    2.0

# %%
df1 = pd.DataFrame(np.arange(6).reshape(3,2),index = ['a','b','c'],columns=['one','two'])
df2 = pd.DataFrame(5 + np.arange(4).reshape(2,2),index = ['a','c'],columns = ['three','four'])

# %%
df1
# Out:
#    one  two
# a    0    1
# b    2    3
# c    4    5

# %%
df2
# Out:
#    three  four
# a      5     6
# c      7     8

# %%
pd.concat([df1,df2],axis = 1)
# Out:
# G:\application\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#    one  two  three  four
# a    0    1    5.0   6.0
# b    2    3    NaN   NaN
# c    4    5    7.0   8.0

# %%
pd.concat([df1,df2],axis = 0)
# Out:
# G:\application\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#    four  one  three  two
# a   NaN  0.0    NaN  1.0
# b   NaN  2.0    NaN  3.0
# c   NaN  4.0    NaN  5.0
# a   6.0  NaN    5.0  NaN
# c   8.0  NaN    7.0  NaN

# %%
pd.concat([df1,df2],axis = 0,ignore_index = True)
# Out:
# G:\application\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#    four  one  three  two
# 0   NaN  0.0    NaN  1.0
# 1   NaN  2.0    NaN  3.0
# 2   NaN  4.0    NaN  5.0
# 3   6.0  NaN    5.0  NaN
# 4   8.0  NaN    7.0  NaN

# %%
data = {'state':['Ohio','Ohio','Ohio','Nevada','Nevada','Nevada'],'year':[2000,2001,2002,2001,2002,2003],
       'pop':[1.5,1.7,3.6,2.4,2.9,3.2]}
frame = pd.DataFrame(data)
frame
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
frame.groupby([frame['state']]).mean()
# Out:
#         year       pop
# state
# Nevada  2002  2.833333
# Ohio    2001  2.266667

# %%
frame.groupby([frame['state'],frame['year']]).mean()
# Out:
#              pop
# state  year
# Nevada 2001  2.4
#        2002  2.9
#        2003  3.2
# Ohio   2000  1.5
#        2001  1.7
#        2002  3.6

# %%
df = pd.DataFrame({'key1':['a', 'a', 'b', 'b', 'a'],
                   'key2':['one', 'two', 'one', 'two', 'one'],
                   'data1':np.random.randn(5),
                   'data2':np.random.randn(5)})
df
# Out:
#   key1 key2     data1     data2
# 0    a  one  0.133968 -1.538707
# 1    a  two  0.174826  1.576341
# 2    b  one  1.495136  0.917847
# 3    b  two -0.497424 -0.042672
# 4    a  one  0.019100 -1.314332

# %%
grouped = df['data1'].groupby(df['key1'])
grouped.mean()
# Out:
# key1
# a    0.109298
# b    0.498856
# Name: data1, dtype: float64

# %%
frame
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
frame.pivot_table(['pop','year'],index = ['state'])
# Out:
#              pop  year
# state
# Nevada  2.833333  2002
# Ohio    2.266667  2001

# %%
df
# Out:
#   key1 key2     data1     data2
# 0    a  one  0.133968 -1.538707
# 1    a  two  0.174826  1.576341
# 2    b  one  1.495136  0.917847
# 3    b  two -0.497424 -0.042672
# 4    a  one  0.019100 -1.314332
